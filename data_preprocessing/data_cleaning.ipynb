# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %%
import os

# Check current working directory
print(os.getcwd())
# Out:
# C:\Users\Hp\RoboAdvisory System\data_preprocessing

# %%
def clean_data(input_path: str, output_path = str):
    df = pd.read_csv(input_path)

    df = df.drop_duplicates()
    df = df.fillna(df.median(numeric_only=True))

    numeric_cols = df.select_dtypes(include=["int64", "float64"]).columns
    scaler = MinMaxScaler()
    df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

    df.to_csv(output_path, index=False)
    print("Saved Sucessfuly")
    return df

# %%
clean_data("../data/created_data.csv", "../data/cleaned_data.csv")
# Out:
# Saved Sucessfuly
#             age    income  dependents  assets  savings_ratio  debt_ratio  \
# 0      0.826087  0.071037        0.50    0.25       0.075567    0.855032
# 1      0.608696  0.612848        0.50    0.50       0.017529    0.029781
# 2      0.304348  0.422352        1.00    0.50       0.135529    0.900398
# 3      0.913043  0.519356        0.00    0.25       0.540593    0.849093
# 4      0.152174  0.419917        1.00    0.00       0.183900    0.836706
# ...         ...       ...         ...     ...            ...         ...
# 99995  0.565217  0.640009        0.75    0.25       0.961991    0.729962
# 99996  0.478261  0.080993        0.50    0.00       0.355134    0.674462
# 99997  0.478261  0.396434        0.00    1.00       0.682066    0.833871
# 99998  0.630435  0.049890        0.25    0.50       0.113007    0.966458
# 99999  0.913043  0.714578        0.75    0.00       0.365865    0.911603
#
#       financial_knowledge     investment_goal    risk_level
# 0                    High          Retirement  Conservative
# 1                    High          Retirement     Aggresive
# 2                  Medium     Wealth Creation     Aggresive
# 3                    High          Retirement     Aggresive
# 4                  Medium     Wealth Creation      Balanced
# ...                   ...                 ...           ...
# 99995                High     Wealth Creation     Aggresive
# 99996                 Low  Short-term Savings  Conservative
# 99997              Medium  Short-term Savings     Aggresive
# 99998                High  Short-term Savings      Balanced
# 99999                 Low           Education  Conservative
#
# [100000 rows x 9 columns]
