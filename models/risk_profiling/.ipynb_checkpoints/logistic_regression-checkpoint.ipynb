# %%
import numpy as np
import pandas as pd
import joblib

# %%
X_train = pd.read_csv("../../data/X_train.csv")
X_test = pd.read_csv("../../data/X_test.csv")

y_train_df = pd.read_csv("../../data/y_train.csv")
y_test_df = pd.read_csv("../../data/y_test.csv")

y_train = (y_train_df.iloc[:, 0].astype(int) - 1).to_numpy()
y_test = (y_test_df.iloc[:, 0].astype(int) - 1).to_numpy()

# %%
class SoftMaxRegression:
    def __init__(self, learning_rate=0.5, epochs=5000, random_state=42):
        np.random.seed(random_state)
        self.learning_rate = learning_rate
        self.epochs = epochs
        self.W = None
        self.b = None

    def _softmax(self, z):
        exp_z = np.exp(z - np.max(z, axis=1, keepdims=True))
        return exp_z / np.sum(exp_z, axis=1, keepdims=True)

    def _one_hot(self, y, num_classes):
        one_hot = np.zeros((y.size, num_classes))
        one_hot[np.arange(y.size), y] = 1
        return one_hot

    def fit(self, X, y):
        n_samples, n_features = X.shape
        num_classes = len(np.unique(y))
        y_encoded = self._one_hot(y, num_classes)

        self.W = np.random.randn(n_features, num_classes) * 0.01
        self.b = np.zeros((1, num_classes))

        for epoch in range(self.epochs):
            logits = np.dot(X, self.W) + self.b
            probs = self._softmax(logits)

            loss = -np.mean(np.sum(y_encoded * np.log(probs + 1e-9), axis=1))

            dW = (1 / n_samples) * np.dot(X.T, (probs - y_encoded))
            db = (1/ n_samples) * np.sum(probs - y_encoded, axis=0, keepdims=True)

            self.W -= self.learning_rate * dW
            self.b -= self.learning_rate * db

            if epoch % 100 == 0:
                print(f"Epoch {epoch}, Loss: {loss:.4f}")

    def predict(self, X):
                logits = np.dot(X, self.W) + self.b
                probs = self._softmax(logits)
                return np.argmax(probs, axis=1)

    def predict_proba(self, X):
        logits = np.dot(X, self.W) + self.b
        return self._softmax(logits)

    def accuracy(self, y_true, y_pred):
                return np.mean(y_true == y_pred)

# %%
model = SoftMaxRegression()
model.fit(X_train, y_train)

preds = model.predict(X_test)
acc = model.accuracy(y_test, preds)

print(f"Test Accuracy: {acc*100:.2f}%")
# Out:
# Epoch 0, Loss: 1.0984
# Epoch 100, Loss: 0.5056
# Epoch 200, Loss: 0.4475
# Epoch 300, Loss: 0.4178
# Epoch 400, Loss: 0.3988
# Epoch 500, Loss: 0.3856
# Epoch 600, Loss: 0.3757
# Epoch 700, Loss: 0.3681
# Epoch 800, Loss: 0.3620
# Epoch 900, Loss: 0.3570
# Epoch 1000, Loss: 0.3529
# Epoch 1100, Loss: 0.3494
# Epoch 1200, Loss: 0.3465
# Epoch 1300, Loss: 0.3439
# Epoch 1400, Loss: 0.3417
# Epoch 1500, Loss: 0.3398
# Epoch 1600, Loss: 0.3381
# Epoch 1700, Loss: 0.3366
# Epoch 1800, Loss: 0.3353
# Epoch 1900, Loss: 0.3341
# Epoch 2000, Loss: 0.3330
# Epoch 2100, Loss: 0.3321
# Epoch 2200, Loss: 0.3312
# Epoch 2300, Loss: 0.3304
# Epoch 2400, Loss: 0.3297
# Epoch 2500, Loss: 0.3291
# Epoch 2600, Loss: 0.3285
# Epoch 2700, Loss: 0.3279
# Epoch 2800, Loss: 0.3275
# Epoch 2900, Loss: 0.3270
# Epoch 3000, Loss: 0.3266
# Epoch 3100, Loss: 0.3262
# Epoch 3200, Loss: 0.3258
# Epoch 3300, Loss: 0.3255
# Epoch 3400, Loss: 0.3252
# Epoch 3500, Loss: 0.3249
# Epoch 3600, Loss: 0.3246
# Epoch 3700, Loss: 0.3244
# Epoch 3800, Loss: 0.3242
# Epoch 3900, Loss: 0.3240
# Epoch 4000, Loss: 0.3238
# Epoch 4100, Loss: 0.3236
# Epoch 4200, Loss: 0.3234
# Epoch 4300, Loss: 0.3232
# Epoch 4400, Loss: 0.3231
# Epoch 4500, Loss: 0.3229
# Epoch 4600, Loss: 0.3228
# Epoch 4700, Loss: 0.3227
# Epoch 4800, Loss: 0.3226
# Epoch 4900, Loss: 0.3225
# Test Accuracy: 85.22%

# %%
#Saving Model for fututre
joblib.dump(model, "../../models/risk_profiling/logisitic_model.joblib")
# Out:
# ['../../models/risk_profiling/logisitic_model.joblib']
